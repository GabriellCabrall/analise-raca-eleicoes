# %%
import pandas as pd

tabela = pd.read_excel('Brasil_final.xlsx')

# %%
partidos = {'NOVO': 'Direita', 'PSOL': 'Esquerda', 'PCB': 'Esquerda', 'PSTU': 'Esquerda', 'PT': 'Esquerda', 'REDE': 'Esquerda', 'PC do B': 'Esquerda', 'PDT': 'Esquerda', 'PV': 'Esquerda', 'PSB': 'Esquerda', 'MDB': 'Direita', 'PSL': 'Direita', 'AVANTE': 'Esquerda', 'PP': 'Direita', 'PRP': 'Direita', 'PRTB': 'Direita', 'PCO': 'Esquerda', 'PRB': 'Direita', 'PPS': 'Esquerda', 'SOLIDARIEDADE': 'Esquerda', 'PSD': 'Direita', 'PSC': 'Direita', 'PODE': 'Direita', 'PROS': 'Direita', 'PMN': 'Esquerda', 'PMB': 'Direita', 'PPL': 'Esquerda', 'PTB': 'Direita', 'PATRIOTA': 'Direita', 'PHS': 'Direita', 'PTC': 'Direita', 'PSDB': 'Esquerda', 'PR': 'Direita', 'DEM': 'Direita', 'DC': 'Direita'}

tabela['Alinhamento'] = tabela['SG_PARTIDO'].map(partidos)

tabela.to_excel('Brasil_final.xlsx', index=False)

# %%
display(tabela)
# Out:
#                       Eleição                      Cor  \
# 0      Candidatos Brasil 2018  Branco / Blanco / White
# 1      Candidatos Brasil 2018  Branco / Blanco / White
# 2      Candidatos Brasil 2018  Branco / Blanco / White
# 3      Candidatos Brasil 2018  Branco / Blanco / White
# 4      Candidatos Brasil 2018  Branco / Blanco / White
# ...                       ...                      ...
# 8583   Candidatos Brasil 2018  Branco / Blanco / White
# 8584   Candidatos Brasil 2018  Branco / Blanco / White
# 8585   Candidatos Brasil 2018  Branco / Blanco / White
# 8586   Candidatos Brasil 2018  Branco / Blanco / White
# 8587   Candidatos Brasil 2018  Branco / Blanco / White
#
#      Teve dificuldade para classificar? Houve erro na exibição da foto  UF  \
# 0                                     N                              N  DF
# 1                                     N                              N  DF
# 2                                     N                              N  DF
# ...
