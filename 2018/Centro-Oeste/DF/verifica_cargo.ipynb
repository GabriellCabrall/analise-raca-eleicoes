# %%
import pandas as pd

tabela_het = pd.read_excel('relatorioDF.xlsx')
tabela_auto = pd.read_csv('consulta_cand_2018_DF.csv', encoding='latin1', sep=';')

# display(tabela_auto.info())
display(tabela_het)
# Out:
#      Código Classificador            Nome Classificador  \
# 0                      16               Guilherme Peres
# 1                      16               Guilherme Peres
# 2                      16               Guilherme Peres
# 3                      16               Guilherme Peres
# 4                      16               Guilherme Peres
# ..                    ...                           ...
# 568                    25   Polyana Moreira de Oliveira
# 569                    25   Polyana Moreira de Oliveira
# 570                    25   Polyana Moreira de Oliveira
# 571                    25   Polyana Moreira de Oliveira
# 572                    25   Polyana Moreira de Oliveira
#
#                      Eleição                              Foto  \
# 0     Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000602344
# 1     Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000602345
# 2     Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000602346
# 3     Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000602347
# 4     Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000602348
# ..                       ...                               ...
# 568   Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000629596
# 569   Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000629607
# 570   Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000629898
# 571   Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000630009
# 572   Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000630086
#
#      SQ_CANDIDATO_x  Código da Cor                       Cor  \
# 0       70000602344              1   Branco / Blanco / White
# 1       70000602345              1   Branco / Blanco / White
# 2       70000602346              1   Branco / Blanco / White
# 3       70000602347              1   Branco / Blanco / White
# 4       70000602348              1   Branco / Blanco / White
# ..              ...            ...                       ...
# 568     70000629596              1   Branco / Blanco / White
# 569     70000629607              2     Preto / Negro / Black
# 570     70000629898              2     Preto / Negro / Black
# 571     70000630009              1   Branco / Blanco / White
# 572     70000630086              1   Branco / Blanco / White
#
#     Teve dificuldade para classificar? Houve erro na exibição da foto  UF  \
# 0                                    N                              N  DF
# 1                                    N                              N  DF
# 2                                    N                              N  DF
# 3                                    N                              N  DF
# 4                                    N                              N  DF
# ..                                 ...                            ...  ..
# 568                                  N                              N  DF
# 569                                  N                              N  DF
# 570                                  N                              N  DF
# 571                                  N                              N  DF
# 572                                  N                              N  DF
#
#      SQ_CANDIDATO_OF  SQ_CANDIDATO_y             Cargo  SQ_CANDIDATO  \
# 0        70000602344     70000602344  DEPUTADO FEDERAL   70000602344
# 1        70000602345     70000602345  DEPUTADO FEDERAL   70000602345
# 2        70000602346     70000602346  DEPUTADO FEDERAL   70000602346
# 3        70000602347     70000602347  DEPUTADO FEDERAL   70000602347
# 4        70000602348     70000602348  DEPUTADO FEDERAL   70000602348
# ..               ...             ...               ...           ...
# 568      70000629596     70000629596  DEPUTADO FEDERAL   70000629596
# 569      70000629607     70000629607  DEPUTADO FEDERAL   70000629607
# 570      70000629898     70000629898  DEPUTADO FEDERAL   70000629898
# 571      70000630009     70000630009  DEPUTADO FEDERAL   70000630009
# 572      70000630086     70000630086  DEPUTADO FEDERAL   70000630086
#
#      DS_GENERO
# 0     FEMININO
# 1    MASCULINO
# 2    MASCULINO
# 3     FEMININO
# 4    MASCULINO
# ..         ...
# 568   FEMININO
# 569  MASCULINO
# 570   FEMININO
# 571  MASCULINO
# 572   FEMININO
#
# [573 rows x 15 columns]

# %%
# Função para verificar se o código está na foto
def verifica_codigo_na_foto(linha):
    for linha1 in tabela_auto.index:
        codigo = str(tabela_auto.loc[linha1, 'SQ_CANDIDATO'])
        if codigo in linha['Foto']:
            codigo = int(codigo)
            return codigo
    return None

# Criação da nova coluna 'SQ_CANDIDATO_OF'
tabela_het['SQ_CANDIDATO_OF'] = tabela_het.apply(verifica_codigo_na_foto, axis=1)

# Exibição dos dataframes
# display(tabela_auto)
# display(tabela_het)
# Out:
#      Código Classificador            Nome Classificador  \
# 0                      16               Guilherme Peres
# 1                      16               Guilherme Peres
# 2                      16               Guilherme Peres
# 3                      16               Guilherme Peres
# 4                      16               Guilherme Peres
# ..                    ...                           ...
# 568                    25   Polyana Moreira de Oliveira
# 569                    25   Polyana Moreira de Oliveira
# 570                    25   Polyana Moreira de Oliveira
# 571                    25   Polyana Moreira de Oliveira
# 572                    25   Polyana Moreira de Oliveira
#
#                      Eleição                              Foto  SQ_CANDIDATO  \
# 0     Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000602344   70000602344
# 1     Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000602345   70000602345
# 2     Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000602346   70000602346
# 3     Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000602347   70000602347
# 4     Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000602348   70000602348
# ..                       ...                               ...           ...
# 568   Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000629596   70000629596
# 569   Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000629607   70000629607
# 570   Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000629898   70000629898
# 571   Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000630009   70000630009
# 572   Candidatos Brasil 2018   BR_2018_FED_TODOS_DF70000630086   70000630086
#
#      Código da Cor                       Cor  \
# 0                1   Branco / Blanco / White
# 1                1   Branco / Blanco / White
# 2                1   Branco / Blanco / White
# 3                1   Branco / Blanco / White
# 4                1   Branco / Blanco / White
# ..             ...                       ...
# 568              1   Branco / Blanco / White
# 569              2     Preto / Negro / Black
# 570              2     Preto / Negro / Black
# 571              1   Branco / Blanco / White
# 572              1   Branco / Blanco / White
#
#     Teve dificuldade para classificar? Houve erro na exibição da foto  UF  \
# 0                                    N                              N  DF
# 1                                    N                              N  DF
# 2                                    N                              N  DF
# 3                                    N                              N  DF
# 4                                    N                              N  DF
# ..                                 ...                            ...  ..
# 568                                  N                              N  DF
# 569                                  N                              N  DF
# 570                                  N                              N  DF
# 571                                  N                              N  DF
# 572                                  N                              N  DF
#
#      SQ_CANDIDATO_OF
# 0        70000602344
# 1        70000602345
# 2        70000602346
# 3        70000602347
# 4        70000602348
# ..               ...
# 568      70000629596
# 569      70000629607
# 570      70000629898
# 571      70000630009
# 572      70000630086
#
# [573 rows x 11 columns]

# %%
# Criação da nova coluna 'Cargo'
tabela_het = pd.merge(tabela_het, tabela_auto[['SQ_CANDIDATO', 'DS_CARGO']], left_on='SQ_CANDIDATO_OF', right_on='SQ_CANDIDATO', how='left')

# Renomeando a coluna 'DS_CARGO' para 'Cargo'
tabela_het.rename(columns={'DS_CARGO': 'Cargo'}, inplace=True)
tabela_het = tabela_het[tabela_het['Cargo'] == 'DEPUTADO FEDERAL']

tabela_het.to_excel('relatorioDF.xlsx', index=False)
