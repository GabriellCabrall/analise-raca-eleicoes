# %%
import pandas as pd

tabela = pd.read_csv('Dep.Federal-2018.csv', sep=';')
tabela.columns = tabela.columns.str.strip()

def transform_foto(foto):
    return foto[18:-11]  # Remove os primeiros 18 e os últimos 11 caracteres
    
# Aplica a função à coluna 'Foto' e renomeia a coluna para 'UF'

tabela['UF'] = tabela['Foto'].apply(transform_foto)

# tabela = tabela.drop('Foto', axis=1)

display(tabela.info())
display(tabela)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25769 entries, 0 to 25768
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Código Classificador                25769 non-null  int64
#  1   Nome Classificador                  25769 non-null  object
#  2   Eleição                             25769 non-null  object
#  3   Foto                                25769 non-null  object
#  4   SQ_CANDIDATO                        25769 non-null  object
#  5   Código da Cor                       25769 non-null  int64
#  6   Cor                                 25769 non-null  object
#  7   Teve dificuldade para classificar?  25769 non-null  object
#  8   Houve erro na exibição da foto      25769 non-null  object
#  9   UF                                  25769 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 2.0+ MB
# None
#        Código Classificador            Nome Classificador  \
# 0                        16               Guilherme Peres
# 1                        16               Guilherme Peres
# 2                        16               Guilherme Peres
# 3                        16               Guilherme Peres
# 4                        16               Guilherme Peres
# ...                     ...                           ...
# 25764                    25   Polyana Moreira de Oliveira
# 25765                    25   Polyana Moreira de Oliveira
# 25766                    25   Polyana Moreira de Oliveira
# 25767                    25   Polyana Moreira de Oliveira
# 25768                    25   Polyana Moreira de Oliveira
#
#                        Eleição                               Foto  \
# 0       Candidatos Brasil 2018    BR_2018_FED_TODOS_AC10000600205
# 1       Candidatos Brasil 2018    BR_2018_FED_TODOS_AC10000600207
# 2       Candidatos Brasil 2018    BR_2018_FED_TODOS_AC10000600209
# 3       Candidatos Brasil 2018    BR_2018_FED_TODOS_AC10000600212
# 4       Candidatos Brasil 2018    BR_2018_FED_TODOS_AC10000600213
# ...                        ...                                ...
# 25764   Candidatos Brasil 2018   BR_2018_FED_TODOS_TO270000629111
# 25765   Candidatos Brasil 2018   BR_2018_FED_TODOS_TO270000629137
# 25766   Candidatos Brasil 2018   BR_2018_FED_TODOS_TO270000629704
# 25767   Candidatos Brasil 2018   BR_2018_FED_TODOS_TO270000630037
# 25768   Candidatos Brasil 2018   BR_2018_FED_TODOS_TO270000630119
#
#       SQ_CANDIDATO  Código da Cor                        Cor  \
# 0      10000600205              1    Branco / Blanco / White
# 1      10000600207              1    Branco / Blanco / White
# 2      10000600209              1    Branco / Blanco / White
# 3      10000600212              1    Branco / Blanco / White
# 4      10000600213              1    Branco / Blanco / White
# ...            ...            ...                        ...
# 25764  2,70001E+11              3   Pardo / “Moreno” / Brown
# 25765  2,70001E+11              1    Branco / Blanco / White
# 25766  2,70001E+11              1    Branco / Blanco / White
# 25767  2,70001E+11              2      Preto / Negro / Black
# 25768  2,70001E+11              1    Branco / Blanco / White
#
#       Teve dificuldade para classificar? Houve erro na exibição da foto    UF
# 0                                      N                              N   _AC
# 1                                      N                              N   _AC
# 2                                      N                              N   _AC
# 3                                      N                              N   _AC
# 4                                      N                              N   _AC
# ...                                  ...                            ...   ...
# 25764                                  N                              N  _TO2
# 25765                                  N                              N  _TO2
# 25766                                  N                              N  _TO2
# 25767                                  N                              N  _TO2
# 25768                                  N                              N  _TO2
#
# [25769 rows x 10 columns]

# %%
# Dicionário de mapeamento de códigos para nomes completos
uf_mapping = {
    '_AC': 'AC',
    '_AL': 'AL',
    '_AM': 'AM',
    '_AP': 'AP',
    '_BA': 'BA',
    '_CE': 'CE',
    '_DF': 'DF',
    '_ES': 'ES',
    '_GO': 'GO',
    '_MA1': 'MA',
    '_MG1': 'MG',
    '_MS1': 'MS',
    '_MT1': 'MT',
    '_PA1': 'PA',
    '_PB1': 'PB',
    '_PE1': 'PE',
    '_PI1': 'PI',
    '_PR1': 'PR',
    '_RJ1': 'RJ',
    '_RN2': 'RN',
    '_RO2': 'RO',
    '_RR2': 'RR',
    '_RS2': 'RS',
    '_SC2': 'SC',
    '_SE2': 'SE',
    '_SP2': 'SP',
    '_TO2': 'TO'
}

# Aplicar o mapeamento à coluna 'UF'
tabela['UF'] = tabela['UF'].map(uf_mapping)

# Agora, a coluna 'UF' contém os nomes completos das unidades federativas

# Se você quiser visualizar o resultado:
display(tabela['UF'].unique())
# Out:
# array(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG',
#        'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR',
#        'RS', 'SC', 'SE', 'SP', 'TO'], dtype=object)

# %%
ufs = list(tabela['UF'].unique())
print(ufs)

for uf in ufs:
    # Filtrar os dados com base na UF
    dados_uf = tabela[tabela['UF'] == uf]
    
    # Nome do arquivo Excel
    nome_arquivo = f'relatorio{uf}.xlsx'
    
    # Salvar os dados em um arquivo Excel
    dados_uf.to_excel(nome_arquivo, index=False)
# Out:
# ['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR', 'RS', 'SC', 'SE', 'SP', 'TO']
