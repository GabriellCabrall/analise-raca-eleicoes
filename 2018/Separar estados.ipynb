# %%
import pandas as pd

tabela = pd.read_csv('Dep.Federal-2018.csv', sep=';')
tabela.columns = tabela.columns.str.strip()

def transform_foto(foto):
    return foto[18:-11]  # Remove os primeiros 18 e os últimos 11 caracteres
    
# Aplica a função à coluna 'Foto' e renomeia a coluna para 'UF'

tabela['UF'] = tabela['Foto'].apply(transform_foto)

tabela = tabela.drop('Foto', axis=1)

display(tabela.info())
display(tabela)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25769 entries, 0 to 25768
# Data columns (total 9 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Código Classificador                25769 non-null  int64
#  1   Nome Classificador                  25769 non-null  object
#  2   Eleição                             25769 non-null  object
#  3   SQ_CANDIDATO                        25769 non-null  object
#  4   Código da Cor                       25769 non-null  int64
#  5   Cor                                 25769 non-null  object
#  6   Teve dificuldade para classificar?  25769 non-null  object
#  7   Houve erro na exibição da foto      25769 non-null  object
#  8   UF                                  25769 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 1.8+ MB
# None
#        Código Classificador            Nome Classificador  ... Houve erro na exibição da foto    UF
# 0                        16               Guilherme Peres  ...                              N   _AC
# 1                        16               Guilherme Peres  ...                              N   _AC
# 2                        16               Guilherme Peres  ...                              N   _AC
# 3                        16               Guilherme Peres  ...                              N   _AC
# 4                        16               Guilherme Peres  ...                              N   _AC
# ...                     ...                           ...  ...                            ...   ...
# 25764                    25   Polyana Moreira de Oliveira  ...                              N  _TO2
# 25765                    25   Polyana Moreira de Oliveira  ...                              N  _TO2
# 25766                    25   Polyana Moreira de Oliveira  ...                              N  _TO2
# 25767                    25   Polyana Moreira de Oliveira  ...                              N  _TO2
# 25768                    25   Polyana Moreira de Oliveira  ...                              N  _TO2
#
# [25769 rows x 9 columns]

# %%
# Dicionário de mapeamento de códigos para nomes completos
uf_mapping = {
    '_AC': 'AC',
    '_AL': 'AL',
    '_AM': 'AM',
    '_AP': 'AP',
    '_BA': 'BA',
    '_CE': 'CE',
    '_DF': 'DF',
    '_ES': 'ES',
    '_GO': 'GO',
    '_MA1': 'MA',
    '_MG1': 'MG',
    '_MS1': 'MS',
    '_MT1': 'MT',
    '_PA1': 'PA',
    '_PB1': 'PB',
    '_PE1': 'PE',
    '_PI1': 'PI',
    '_PR1': 'PR',
    '_RJ1': 'RJ',
    '_RN2': 'RN',
    '_RO2': 'RO',
    '_RR2': 'RR',
    '_RS2': 'RS',
    '_SC2': 'SC',
    '_SE2': 'SE',
    '_SP2': 'SP',
    '_TO2': 'TO'
}

# Aplicar o mapeamento à coluna 'UF'
tabela['UF'] = tabela['UF'].map(uf_mapping)

# Agora, a coluna 'UF' contém os nomes completos das unidades federativas

# Se você quiser visualizar o resultado:
display(tabela['UF'].unique())
# Out:
# array(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG',
#        'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR',
#        'RS', 'SC', 'SE', 'SP', 'TO'], dtype=object)

# %%
ufs = list(tabela['UF'].unique())
print(ufs)

for uf in ufs:
    # Filtrar os dados com base na UF
    dados_uf = tabela[tabela['UF'] == uf]
    
    # Nome do arquivo Excel
    nome_arquivo = f'relatorio{uf}.xlsx'
    
    # Salvar os dados em um arquivo Excel
    dados_uf.to_excel(nome_arquivo, index=False)
# Out:
# ['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR', 'RS', 'SC', 'SE', 'SP', 'TO']
