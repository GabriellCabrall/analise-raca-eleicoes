# %%
import pandas as pd
tabela = pd.read_csv('relatorioAL.csv', sep=';')
tabela.columns = tabela.columns.str.replace('"', '')
tabela["Código Classificador"] = tabela["Código Classificador"].str.replace('"', '')
tabela["Código Classificador"] = tabela["Código Classificador"].astype(int)
tabela = tabela.rename(columns={" Código da Cor": "Código da Cor"})
print(tabela.columns)
tabela["Código da Cor"] = tabela["Código da Cor"].str.replace('"', '')
tabela["Código da Cor"] = tabela["Código da Cor"].astype(int)
#print(tabela['Código Classificador'])
display(tabela) 
# print(tabela.info)
# Out:
# Index(['Código Classificador', ' Nome Classificador', ' Eleição', ' Foto',
#        ' SQ_CANDIDATO', 'Código da Cor', ' Cor',
#        ' Teve dificuldade para classificar?',
#        ' Houve erro na exibição da foto '],
#       dtype='object')
#       Código Classificador                     Nome Classificador  \
# 0                       14   "Nathália de Souza Silva Grigorievs"
# 1                       14   "Nathália de Souza Silva Grigorievs"
# 2                       14   "Nathália de Souza Silva Grigorievs"
# 3                       14   "Nathália de Souza Silva Grigorievs"
# 4                       14   "Nathália de Souza Silva Grigorievs"
# ...                    ...                                    ...
# 1165                    27                      "Giovanne Picolo"
# 1166                    27                      "Giovanne Picolo"
# 1167                    27                      "Giovanne Picolo"
# 1168                    27                      "Giovanne Picolo"
# 1169                    27                      "Giovanne Picolo"
#
#                                           Eleição  \
# 0      "Candidaturas Majoritárias 2022 - Alagoas"
# 1      "Candidaturas Majoritárias 2022 - Alagoas"
# 2      "Candidaturas Majoritárias 2022 - Alagoas"
# 3      "Candidaturas Majoritárias 2022 - Alagoas"
# 4      "Candidaturas Majoritárias 2022 - Alagoas"
# ...                                           ...
# 1165   "Candidaturas Majoritárias 2022 - Alagoas"
# 1166   "Candidaturas Majoritárias 2022 - Alagoas"
# 1167   "Candidaturas Majoritárias 2022 - Alagoas"
# 1168   "Candidaturas Majoritárias 2022 - Alagoas"
# 1169   "Candidaturas Majoritárias 2022 - Alagoas"
#
#                                             Foto    SQ_CANDIDATO  \
# 0      "foto_cand2022_AL_div/FAL20001698524_div"   "20001698524"
# 1      "foto_cand2022_AL_div/FAL20001698127_div"   "20001698127"
# 2      "foto_cand2022_AL_div/FAL20001719178_div"   "20001719178"
# 3      "foto_cand2022_AL_div/FAL20001653095_div"   "20001653095"
# 4      "foto_cand2022_AL_div/FAL20001697696_div"   "20001697696"
# ...                                          ...             ...
# 1165   "foto_cand2022_AL_div/FAL20001653895_div"   "20001653895"
# 1166   "foto_cand2022_AL_div/FAL20001697699_div"   "20001697699"
# 1167   "foto_cand2022_AL_div/FAL20001719176_div"   "20001719176"
# 1168   "foto_cand2022_AL_div/FAL20001724820_div"   "20001724820"
# 1169   "foto_cand2022_AL_div/FAL20001651899_div"   "20001651899"
#
#       Código da Cor                          Cor  \
# 0                 1    "Branco / Blanco / White"
# 1                 1    "Branco / Blanco / White"
# 2                 1    "Branco / Blanco / White"
# 3                 1    "Branco / Blanco / White"
# 4                 1    "Branco / Blanco / White"
# ...             ...                          ...
# 1165              1    "Branco / Blanco / White"
# 1166              1    "Branco / Blanco / White"
# 1167              3   "Pardo / “Moreno” / Brown"
# 1168              1    "Branco / Blanco / White"
# 1169              1    "Branco / Blanco / White"
#
#       Teve dificuldade para classificar?  Houve erro na exibição da foto
# 0                                    "N"                              "N"
# 1                                    "N"                              "N"
# 2                                    "N"                              "N"
# 3                                    "N"                              "N"
# 4                                    "N"                              "N"
# ...                                  ...                              ...
# 1165                                 "N"                              "N"
# 1166                                 "N"                              "N"
# 1167                                 "N"                              "N"
# 1168                                 "S"                              "S"
# 1169                                 "N"                              "N"
#
# [1170 rows x 9 columns]

# %%
# obter os valores únicos da coluna "Código Classificador"
valores_unicos = list(tabela["Código Classificador"].unique())


# criar uma tabela separada para cada valor único
tabelas_separadas = {}

for valor in valores_unicos:
    tabela_separada = tabela[tabela["Código Classificador"] == valor]
    tabelas_separadas[valor] = tabela_separada

for valor, tabela_separada in tabelas_separadas.items():
    total_linhas = len(tabela_separada)
    serie_contagem = tabela_separada[" Cor"].value_counts()
    serie_incidencia = serie_contagem.div(total_linhas).mul(100)
    print(f"Incidência da cor na tabela para o valor {valor}:")
    print('{}'.format(serie_incidencia))
# Out:
# Incidência da cor na tabela para o valor 14:
#  "Branco / Blanco / White"        75.897436
#  "Preto / Negro / Black"          17.435897
#  "Pardo / “Moreno” / Brown"        6.153846
#  "Amarelo / Amarillo / Yellow"     0.512821
# Name:  Cor, dtype: float64
# Incidência da cor na tabela para o valor 20:
#  "Branco / Blanco / White"        78.461538
#  "Pardo / “Moreno” / Brown"       14.871795
#  "Preto / Negro / Black"           6.153846
#  "Amarelo / Amarillo / Yellow"     0.512821
# Name:  Cor, dtype: float64
# Incidência da cor na tabela para o valor 21:
#  "Branco / Blanco / White"        59.487179
#  "Pardo / “Moreno” / Brown"       31.794872
#  "Preto / Negro / Black"           8.205128
#  "Amarelo / Amarillo / Yellow"     0.512821
# Name:  Cor, dtype: float64
# Incidência da cor na tabela para o valor 22:
#  "Branco / Blanco / White"     81.538462
#  "Pardo / “Moreno” / Brown"    16.923077
#  "Preto / Negro / Black"        1.538462
# Name:  Cor, dtype: float64
# Incidência da cor na tabela para o valor 23:
#  "Branco / Blanco / White"     65.128205
#  "Pardo / “Moreno” / Brown"    27.179487
#  "Preto / Negro / Black"        7.692308
# Name:  Cor, dtype: float64
# Incidência da cor na tabela para o valor 27:
#  "Branco / Blanco / White"        71.282051
#  "Pardo / “Moreno” / Brown"       18.461538
#  "Preto / Negro / Black"           7.692308
#  "Amarelo / Amarillo / Yellow"     2.564103
# Name:  Cor, dtype: float64

# %%
tabelas_separadas = {}

for valor in valores_unicos:
    tabela_separada = tabela[tabela["Código Classificador"] == valor]
    tabelas_separadas[valor] = tabela_separada
    
display(tabelas_separadas[14])
# Out:
#      Código Classificador                     Nome Classificador  \
# 0                      14   "Nathália de Souza Silva Grigorievs"
# 1                      14   "Nathália de Souza Silva Grigorievs"
# 2                      14   "Nathália de Souza Silva Grigorievs"
# 3                      14   "Nathália de Souza Silva Grigorievs"
# 4                      14   "Nathália de Souza Silva Grigorievs"
# ..                    ...                                    ...
# 190                    14   "Nathália de Souza Silva Grigorievs"
# 191                    14   "Nathália de Souza Silva Grigorievs"
# 192                    14   "Nathália de Souza Silva Grigorievs"
# 193                    14   "Nathália de Souza Silva Grigorievs"
# 194                    14   "Nathália de Souza Silva Grigorievs"
#
#                                          Eleição  \
# 0     "Candidaturas Majoritárias 2022 - Alagoas"
# 1     "Candidaturas Majoritárias 2022 - Alagoas"
# 2     "Candidaturas Majoritárias 2022 - Alagoas"
# 3     "Candidaturas Majoritárias 2022 - Alagoas"
# 4     "Candidaturas Majoritárias 2022 - Alagoas"
# ..                                           ...
# 190   "Candidaturas Majoritárias 2022 - Alagoas"
# 191   "Candidaturas Majoritárias 2022 - Alagoas"
# 192   "Candidaturas Majoritárias 2022 - Alagoas"
# 193   "Candidaturas Majoritárias 2022 - Alagoas"
# 194   "Candidaturas Majoritárias 2022 - Alagoas"
#
#                                            Foto    SQ_CANDIDATO  \
# 0     "foto_cand2022_AL_div/FAL20001698524_div"   "20001698524"
# 1     "foto_cand2022_AL_div/FAL20001698127_div"   "20001698127"
# 2     "foto_cand2022_AL_div/FAL20001719178_div"   "20001719178"
# 3     "foto_cand2022_AL_div/FAL20001653095_div"   "20001653095"
# 4     "foto_cand2022_AL_div/FAL20001697696_div"   "20001697696"
# ..                                          ...             ...
# 190   "foto_cand2022_AL_div/FAL20001653895_div"   "20001653895"
# 191   "foto_cand2022_AL_div/FAL20001697699_div"   "20001697699"
# 192   "foto_cand2022_AL_div/FAL20001719176_div"   "20001719176"
# 193   "foto_cand2022_AL_div/FAL20001724820_div"   "20001724820"
# 194   "foto_cand2022_AL_div/FAL20001651899_div"   "20001651899"
#
#      Código da Cor                         Cor  \
# 0                1   "Branco / Blanco / White"
# 1                1   "Branco / Blanco / White"
# 2                1   "Branco / Blanco / White"
# 3                1   "Branco / Blanco / White"
# 4                1   "Branco / Blanco / White"
# ..             ...                         ...
# 190              1   "Branco / Blanco / White"
# 191              1   "Branco / Blanco / White"
# 192              2     "Preto / Negro / Black"
# 193              1   "Branco / Blanco / White"
# 194              1   "Branco / Blanco / White"
#
#      Teve dificuldade para classificar?  Houve erro na exibição da foto
# 0                                   "N"                              "N"
# 1                                   "N"                              "N"
# 2                                   "N"                              "N"
# 3                                   "N"                              "N"
# 4                                   "N"                              "N"
# ..                                  ...                              ...
# 190                                 "N"                              "N"
# 191                                 "N"                              "N"
# 192                                 "N"                              "N"
# 193                                 "S"                              "S"
# 194                                 "N"                              "N"
#
# [195 rows x 9 columns]

# %%
media_branco = (75.897436 + 78.461538 + 59.487179 + 81.538462 + 65.128205 + 71.282051) / 6
print(media_branco)
media_pardo = (17.435897 + 14.871795 + 31.794872 + 16.923077 + 27.179487 + 18.461538) / 6
print(media_pardo)
media_preto = (6.153846 + 6.153846 + 8.205128 + 1.538462 + 7.692308 + 7.692308) / 6
print(media_preto)
media_amarelo = (0.512821 + 0.512821 + 0.512821 + 2.564103) / 6
print(media_amarelo)
# Out:
# 71.96581183333332
# 21.111111
# 6.239316333333332
# 0.683761
