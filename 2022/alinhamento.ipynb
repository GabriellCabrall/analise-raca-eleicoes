# %%
import pandas as pd

tabela = pd.read_excel('Brasil_final.xlsx')

display(tabela)
# Out:
#                                                  Eleição  \
# 0       "Candidaturas Majoritárias 2022 - Distrito Fe...
# 1       "Candidaturas Majoritárias 2022 - Distrito Fe...
# 2       "Candidaturas Majoritárias 2022 - Distrito Fe...
# 3       "Candidaturas Majoritárias 2022 - Distrito Fe...
# 4       "Candidaturas Majoritárias 2022 - Distrito Fe...
# ...                                                  ...
# 10173   "Candidaturas Majoritárias 2022 - Santa Catar...
# 10174   "Candidaturas Majoritárias 2022 - Santa Catar...
# 10175   "Candidaturas Majoritárias 2022 - Santa Catar...
# 10176   "Candidaturas Majoritárias 2022 - Santa Catar...
# 10177   "Candidaturas Majoritárias 2022 - Santa Catar...
#
#                              Cor Teve dificuldade para classificar?  \
# 0                         Branco                                "N"
# 1                          Preto                                "N"
# 2                         Branco                                "N"
# ...

# %%
partido = tabela['SG_PARTIDO'].unique()

print(len(partido))

dicionario_partidos = dict.fromkeys(partido, '')
print(dicionario_partidos)
# Out:
# 32
# {'PT': '', 'PC do B': '', 'PV': '', 'NOVO': '', 'PSOL': '', 'REDE': '', 'PMN': '', 'UNIÃO': '', 'AVANTE': '', 'PRTB': '', 'AGIR': '', 'UP': '', 'PROS': '', 'PSTU': '', 'REPUBLICANOS': '', 'PL': '', 'PDT': '', 'PODE': '', 'PSB': '', 'SOLIDARIEDADE': '', 'PP': '', 'MDB': '', 'PSDB': '', 'DC': '', 'PSD': '', 'PTB': '', 'PCO': '', 'PATRIOTA': '', 'CIDADANIA': '', 'PSC': '', 'PCB': '', 'PMB': ''}
