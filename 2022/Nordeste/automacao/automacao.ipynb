# %%
import pandas as pd
from unidecode import unidecode

tabela = pd.read_excel('variáveis.xlsx')
tabela = tabela.tail(69)
tabela['Município'] = tabela['Município'].apply(lambda x: unidecode(x) if isinstance(x, str) else x)
tabela['Município'] = tabela['Município'].str[:-5]
tabela['Partido Governador'] = tabela['Partido Governador'].str[5:]
tabela['Partido Governador'] = tabela['Partido Governador'].astype(str)
display(tabela)
print(tabela['Ano de Criação'].unique())
# Out:
#      Ano de Criação                            Unidade de Conservação   \
# 199            2006  RESERVA EXTRATIVISTA DO RECANTO DAS ARARAS DE ...
# 200            2006                 RESERVA EXTRATIVISTA LAGO DO CEDRO
# 201            2006                  PARQUE ESTADUAL DA MATA ATLÂNTICA
# 202            2006  ÁREA DE RELEVANTE INTERESSE ECOLÓGICO DA CABEC...
# 203            2006       ÁREA DE PROTEÇÃO AMBIENTAL VARGEM DAS FLORES
# ..              ...                                                ...
# 263            2010  PARQUE NATURAL MUNICIPAL VOÇOROCA DO LAR DOS I...
# 264            2010  ÁREA DE PROTEÇÃO AMBIENTAL DA SUB BACIA DO RIO...
# 265            2010                         ESTAÇÃO ECOLÓGICA DE AVARÉ
# 266            2010  RESERVA PARTICULAR DO PATRIMÔNIO NATURAL CATED...
# 267            2010   RESERVA PARTICULAR DO PATRIMÔNIO NATURAL SONHADA
#
#                           Categoria de Manejo  \
# 199                      Reserva Extrativista
# 200                      Reserva Extrativista
# 201                                    Parque
# 202     Área de Relevante Interesse Ecológico
# 203                Área de Proteção Ambiental
# ..                                        ...
# 263                                    Parque
# 264                Área de Proteção Ambiental
# 265                         Estação Ecológica
# 266  Reserva Particular do Patrimônio Natural
# 267  Reserva Particular do Patrimônio Natural
#
#                                           Orgão Gestor Esfera Administrativa  \
# 199  Instituto Chico Mendes de Conservação da Biodi...               Federal
# 200  Instituto Chico Mendes de Conservação da Biodi...               Federal
# 201  Secretaria Estadual do Meio Ambiente e dos Rec...              Estadual
# 202  Secretaria de Meio Ambiente e Agricultura Sust...             Municipal
# 203    Instituto Estadual de Florestas de Minas Gerais              Estadual
# ..                                                 ...                   ...
# 263              Prefeitura Municipal de Nazareno - MG             Municipal
# 264  Superintendência Municipal de Meio Ambiente de...             Municipal
# 265  Fundação para Conservação e a Produção Florest...              Estadual
# 266  Instituto Chico Mendes de Conservação da Biodi...               Federal
# 267  Instituto Chico Mendes de Conservação da Biodi...               Federal
#
#     Estado               Município  Aporte Populacional Partido Governador  \
# 199     GO            Sao Domingos                  NaN                 PP
# 200     GO                  Aruana                  NaN                 PP
# 201     GO              Agua Limpa                  NaN                nan
# 202     GO   Alto Paraiso de Goias                  NaN                 PP
# 203     MG    Betim (MG), Contagem                  NaN               PSDB
# ..     ...                     ...                  ...                ...
# 263     MG                Nazareno                  NaN               PSDB
# 264     MS              Bataguassu                  NaN               PMDB
# 265     SP                   Avare                  NaN               PSDB
# 266     TO  Sao Felix do Tocantins                  NaN               PMDB
# 267     TO                    Pium                  NaN               PMDB
#
#     Partido Prefeito Há alinhamento?
# 199         PSDB\nPT             NaN
# 200        PSDC (DC)             NaN
# 201                ?             NaN
# 202        PFL (DEM)             NaN
# 203         PSDB\nPT             NaN
# ..               ...             ...
# 263              NaN             NaN
# 264               PT             NaN
# 265             PSDB             NaN
# 266               PR             NaN
# 267             PMDB             NaN
#
# [69 rows x 11 columns]
# [2006 2007 2008 2009 2010]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
import time

for linha in tabela.index:
    navegador.get('https://eleicoes.poder360.com.br')

    navegador.find_element(By.ID, 'id_cargo').send_keys('Prefeito')
    ano = tabela.loc[linha, 'Ano de Criação']

    if ano == 2006 or ano == 2007 or ano == 2008:
        ano_preencher = 2004
        navegador.find_element(By.ID, 'id_ano').send_keys(ano_preencher)
    else:
        ano_preencher = 2008
        navegador.find_element(By.ID, 'id_ano').send_keys(ano_preencher)
    navegador.find_element(By.ID, 'id_uf').send_keys(tabela.loc[linha, 'Estado'])
    navegador.find_element(By.ID, 'id_municipio').send_keys(tabela.loc[linha, 'Município'])
    navegador.find_element(By.XPATH, '//*[@id="main"]/div[1]/form/input').click()

    partido_governador = tabela.loc[linha, 'Partido Governador']
    
    lista = navegador.find_elements(By.CLASS_NAME, 'box-politicos__candidato-dados')

    if len(lista) >= 1:
        for i in range(len(lista)):
            elemento = lista[i]
            elemento.click()
            # verificar se foi eleito
            texto = navegador.find_element(By.XPATH, f'//*[@id="year-{ano_preencher}"]/div[2]/div/table[2]/tbody/tr[1]/td[2]').text
            if texto == 'Eleito' or texto == 'Eleita':
                partido_eleito = navegador.find_element(By.XPATH, f'//*[@id="year-{ano_preencher}"]/div[2]/div/table[1]/tbody/tr[8]/td[2]/acronym').text
                coalizao_eleito = navegador.find_element(By.XPATH, f'//*[@id="year-{ano_preencher}"]/div[2]/div/table[1]/tbody/tr[9]/td[2]').text

                if partido_governador != 'NaN':
                    if partido_governador in partido_eleito:
                        tabela.loc[linha, 'Há alinhamento?'] = 'Há alinhamento de partido'
                    elif partido_governador in coalizao_eleito:
                        tabela.loc[linha, 'Há alinhamento?'] = 'Há alinhamento de coligação'
                    elif partido_governador not in partido_eleito and partido_governador not in coalizao_eleito:
                        tabela.loc[linha, 'Há alinhamento?'] = 'Não há alinhamento'
                    else:
                        tabela.loc[linha, 'Há alinhamento?'] = '-'
                    break
                else:
                    tabela.loc[linha, 'Há alinhamento?'] = '-'
                    break
            elif texto == 'Não eleito' or texto == 'NÃO ELEITO' or texto == 'Não eleita' or texto == 'NÃO ELEITA':
                navegador.back()
                lista = navegador.find_elements(By.CLASS_NAME, 'box-politicos__candidato-dados')
                elemento = lista[i + 1]
                # time.sleep(2)
                elemento.click()
                partido_eleito = navegador.find_element(By.XPATH, f'//*[@id="year-{ano_preencher}"]/div[2]/div/table[1]/tbody/tr[8]/td[2]/acronym').text
                coalizao_eleito = navegador.find_element(By.XPATH, f'//*[@id="year-{ano_preencher}"]/div[2]/div/table[1]/tbody/tr[9]/td[2]').text

                if partido_governador != 'NaN':
                    if partido_governador in partido_eleito:
                        tabela.loc[linha, 'Há alinhamento?'] = 'Há alinhamento de partido'
                    elif partido_governador in coalizao_eleito:
                        tabela.loc[linha, 'Há alinhamento?'] = 'Há alinhamento de coligação'
                    elif partido_governador not in partido_eleito and partido_governador not in coalizao_eleito:
                        tabela.loc[linha, 'Há alinhamento?'] = 'Não há alinhamento'
                    else:
                        tabela.loc[linha, 'Há alinhamento?'] = '-'
                    break
                else:
                    tabela.loc[linha, 'Há alinhamento?'] = '-'
                    break
            else:
                navegador.back()
                lista = navegador.find_elements(By.CLASS_NAME, 'box-politicos__candidato-dados')
                elemento = lista[i + 1]
                # time.sleep(2)
                elemento.click()
                partido_eleito = navegador.find_element(By.XPATH, f'//*[@id="year-{ano_preencher}"]/div[2]/div/table[1]/tbody/tr[8]/td[2]/acronym').text
                coalizao_eleito = navegador.find_element(By.XPATH, f'//*[@id="year-{ano_preencher}"]/div[2]/div/table[1]/tbody/tr[9]/td[2]').text

                if partido_governador != 'NaN':
                    if partido_governador in partido_eleito:
                        tabela.loc[linha, 'Há alinhamento?'] = 'Há alinhamento de partido'
                    elif partido_governador in coalizao_eleito:
                        tabela.loc[linha, 'Há alinhamento?'] = 'Há alinhamento de coligação'
                    else:
                        tabela.loc[linha, 'Há alinhamento?'] = '-'
                    break
                else:
                    tabela.loc[linha, 'Há alinhamento?'] = '-'
                    break
    else:
        tabela.loc[linha, 'Há alinhamento?'] = '-'
        continue
    
display(tabela)

tabela.to_excel('Atualização de alinhamento.xlsx', index=False)

    # proximos passos:
    # verificar se o partido do eleito é igual o partido do governador
    # se for igual escrever há alinhamento de partido, se não for ir pro próximo passo
    # verificar se o partido do governador está na coalizao do eleito, se tiver escrever há alinhamento de coalizão, se não houver não escrever nada
# Out:
#      Ano de Criação                            Unidade de Conservação   \
# 199            2006  RESERVA EXTRATIVISTA DO RECANTO DAS ARARAS DE ...
# 200            2006                 RESERVA EXTRATIVISTA LAGO DO CEDRO
# 201            2006                  PARQUE ESTADUAL DA MATA ATLÂNTICA
# 202            2006  ÁREA DE RELEVANTE INTERESSE ECOLÓGICO DA CABEC...
# 203            2006       ÁREA DE PROTEÇÃO AMBIENTAL VARGEM DAS FLORES
# ..              ...                                                ...
# 263            2010  PARQUE NATURAL MUNICIPAL VOÇOROCA DO LAR DOS I...
# 264            2010  ÁREA DE PROTEÇÃO AMBIENTAL DA SUB BACIA DO RIO...
# 265            2010                         ESTAÇÃO ECOLÓGICA DE AVARÉ
# 266            2010  RESERVA PARTICULAR DO PATRIMÔNIO NATURAL CATED...
# 267            2010   RESERVA PARTICULAR DO PATRIMÔNIO NATURAL SONHADA
#
#                           Categoria de Manejo  \
# 199                      Reserva Extrativista
# 200                      Reserva Extrativista
# 201                                    Parque
# 202     Área de Relevante Interesse Ecológico
# 203                Área de Proteção Ambiental
# ..                                        ...
# 263                                    Parque
# 264                Área de Proteção Ambiental
# 265                         Estação Ecológica
# 266  Reserva Particular do Patrimônio Natural
# 267  Reserva Particular do Patrimônio Natural
#
#                                           Orgão Gestor Esfera Administrativa  \
# 199  Instituto Chico Mendes de Conservação da Biodi...               Federal
# 200  Instituto Chico Mendes de Conservação da Biodi...               Federal
# 201  Secretaria Estadual do Meio Ambiente e dos Rec...              Estadual
# 202  Secretaria de Meio Ambiente e Agricultura Sust...             Municipal
# 203    Instituto Estadual de Florestas de Minas Gerais              Estadual
# ..                                                 ...                   ...
# 263              Prefeitura Municipal de Nazareno - MG             Municipal
# 264  Superintendência Municipal de Meio Ambiente de...             Municipal
# 265  Fundação para Conservação e a Produção Florest...              Estadual
# 266  Instituto Chico Mendes de Conservação da Biodi...               Federal
# 267  Instituto Chico Mendes de Conservação da Biodi...               Federal
#
#     Estado               Município  Aporte Populacional Partido Governador  \
# 199     GO            Sao Domingos                  NaN                 PP
# 200     GO                  Aruana                  NaN                 PP
# 201     GO              Agua Limpa                  NaN                nan
# 202     GO   Alto Paraiso de Goias                  NaN                 PP
# 203     MG    Betim (MG), Contagem                  NaN               PSDB
# ..     ...                     ...                  ...                ...
# 263     MG                Nazareno                  NaN               PSDB
# 264     MS              Bataguassu                  NaN               PMDB
# 265     SP                   Avare                  NaN               PSDB
# 266     TO  Sao Felix do Tocantins                  NaN               PMDB
# 267     TO                    Pium                  NaN               PMDB
#
#     Partido Prefeito              Há alinhamento?
# 199         PSDB\nPT  Há alinhamento de coligação
# 200        PSDC (DC)  Há alinhamento de coligação
# 201                ?           Não há alinhamento
# 202        PFL (DEM)                            -
# 203         PSDB\nPT                            -
# ..               ...                          ...
# 263              NaN    Há alinhamento de partido
# 264               PT           Não há alinhamento
# 265             PSDB    Há alinhamento de partido
# 266               PR           Não há alinhamento
# 267             PMDB    Há alinhamento de partido
#
# [69 rows x 11 columns]

# %%
display(tabela.columns)
# Out:
# Index(['Ano de Criação', 'Unidade de Conservação ', 'Categoria de Manejo',
#        'Orgão Gestor', 'Esfera Administrativa', 'Estado', 'Município',
#        'Aporte Populacional', 'Partido Governador', 'Partido Prefeito',
#        'Há alinhamento?'],
#       dtype='object')
